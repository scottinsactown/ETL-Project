# %%
import pandas as pd
import sqlalchemy

# %%
data = pd.read_csv(r"C:\Users\graha\Downloads\20190101_20190117_SLD_FCST_ACTUAL_20191217_17_43_34_v1\20190101_20190117_SLD_FCST_ACTUAL_20191217_17_43_34_v1.csv")
data.head()
# Out:
#        INTERVALSTARTTIME_GMT        INTERVALENDTIME_GMT  LOAD_TYPE  \
# 0  2019-01-01T23:00:00-00:00  2019-01-02T00:00:00-00:00          0
# 1  2019-01-02T00:00:00-00:00  2019-01-02T01:00:00-00:00          0
# 2  2019-01-01T12:00:00-00:00  2019-01-01T13:00:00-00:00          0
# 3  2019-01-01T16:00:00-00:00  2019-01-01T17:00:00-00:00          0
# 4  2019-01-01T18:00:00-00:00  2019-01-01T19:00:00-00:00          0
#
#        OPR_DT  OPR_HR  OPR_INTERVAL MARKET_RUN_ID TAC_AREA_NAME  \
# 0  2019-01-01      16             0        ACTUAL          AZPS
# 1  2019-01-01      17             0        ACTUAL          AZPS
# 2  2019-01-01       5             0        ACTUAL          AZPS
# 3  2019-01-01       9             0        ACTUAL          AZPS
# 4  2019-01-01      11             0        ACTUAL          AZPS
#
#                                  LABEL    XML_DATA_ITEM  POS    MW  \
# 0  Total Actual Hourly Integrated Load  SYS_FCST_ACT_MW  3.8  2949
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5376 entries, 0 to 5375
# Data columns (total 14 columns):
# INTERVALSTARTTIME_GMT    5376 non-null object
# INTERVALENDTIME_GMT      5376 non-null object
# LOAD_TYPE                5376 non-null int64
# OPR_DT                   5376 non-null object
# OPR_HR                   5376 non-null int64
# OPR_INTERVAL             5376 non-null int64
# MARKET_RUN_ID            5376 non-null object
# TAC_AREA_NAME            5376 non-null object
# LABEL                    5376 non-null object
# XML_DATA_ITEM            5376 non-null object
# POS                      5376 non-null float64
# MW                       5376 non-null int64
# EXECUTION_TYPE           5376 non-null object
# GROUP                    5376 non-null int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 588.1+ KB

# %%
test_group = data.groupby(['OPR_DT', 'OPR_HR'])
test = pd.DataFrame(test_group['MW'].sum()).reset_index()
test.rename(columns={
    'OPR_DT':'Date',
    'OPR_HR':'Hour',
    'MW':'Demand MW'
}, inplace=True)
test.head()
# Out:
#          Date  Hour  Demand MW
# 0  2019-01-01     1      73502
# 1  2019-01-01     2      71488
# 2  2019-01-01     3      70058
# 3  2019-01-01     4      69474
# 4  2019-01-01     5      70032

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 384 entries, 0 to 383
# Data columns (total 3 columns):
# Date         384 non-null object
# Hour         384 non-null int64
# Demand MW    384 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 9.1+ KB

# %%
test
# Out:
#            Date  Hour  Demand MW
# 0    2019-01-01     1      73502
# 1    2019-01-01     2      71488
# 2    2019-01-01     3      70058
# 3    2019-01-01     4      69474
# 4    2019-01-01     5      70032
# 5    2019-01-01     6      71811
# 6    2019-01-01     7      74224
# 7    2019-01-01     8      74745
# 8    2019-01-01     9      73903
# 9    2019-01-01    10      72840
# 10   2019-01-01    11      71506
# 11   2019-01-01    12      69849
# 12   2019-01-01    13      68410
# 13   2019-01-01    14      68109
# 14   2019-01-01    15      69356
# 15   2019-01-01    16      72647
# 16   2019-01-01    17      79788
# 17   2019-01-01    18      88055
# 18   2019-01-01    19      89302
# 19   2019-01-01    20      88474
# 20   2019-01-01    21      86872
# 21   2019-01-01    22      83592
# 22   2019-01-01    23      78811
# 23   2019-01-01    24      74373
# 24   2019-01-02     1      71625
# 25   2019-01-02     2      69927
# 26   2019-01-02     3      69302
# ...
